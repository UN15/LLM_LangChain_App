# %% [markdown]
# ### 문제 3-1 :  콘텐츠분쟁해결 RAG 시스템

# %%
import os
from dotenv import load_dotenv

load_dotenv()
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_openai import OpenAIEmbeddings, ChatOpenAI
from langchain_community.document_loaders import PyPDFLoader
from langchain_community.vectorstores import FAISS
from langchain.chains import RetrievalQA
from langchain.prompts import PromptTemplate

loader = PyPDFLoader('../data/콘텐츠분쟁해결_사례.pdf')
documents = loader.load()
print(f"  총 {len(documents)}페이지 로드 완료")
# Out:
#   총 109페이지 로드 완료

# %%
splitter = RecursiveCharacterTextSplitter(
    chunk_size=1500,        #  법률 사례는 1200-1800자 권장
    chunk_overlap=300,      #  사례 맥락 보존을 위해 200-400자
    separators=[
        "\n【사건개요】",     #  법률 문서 섹션 구분자
        "\n【쟁점사항】",     #  쟁점 부분 구분
        "\n【처리경위】",     #  처리 과정 구분
        "\n【처리결과】",     #  결과 부분 구분
        "\n■", "\n\n", "\n", ".", " ", ""
    ]
)
chunks = splitter.split_documents(documents)

embeddings = OpenAIEmbeddings(
    model="text-embedding-3-large",  #  한국어 법률 용어에 최적
    dimensions=1536                  #  고성능 임베딩 차원
)

vectorstore = FAISS.from_documents(chunks, embeddings)
print(f" FAISS 벡터스토어 생성 완료 ({len(chunks)}개 벡터)")

retriever = vectorstore.as_retriever(
    search_type="similarity",        #  또는 "mmr" (다양성 고려시)
    search_kwargs={"k": 5}          #  상위 5개 관련 사례 검색
)

llm = ChatOpenAI(
    model="gpt-4o",                 #  또는 "gpt-4o-mini" (경제적)
    temperature=0.2,                #  법률 조언은 정확성 중시
    max_tokens=2000                 #  충분한 답변 길이
)

prompt_template = """
당신은 콘텐츠 분야 전문 법률 자문사입니다. 
아래 분쟁조정 사례들을 바탕으로 정확하고 전문적인 법률 조언을 제공해주세요.

관련 분쟁사례:
{context}

상담 내용: {question}

답변 가이드라인:
1. 제시된 사례들을 근거로 답변하세요                    # 사례 기반 답변
2. 관련 법령이나 조항이 있다면 명시하세요               # 법적 근거 제시
3. 비슷한 사례의 처리경위와 결과를 참고하여 설명하세요    # 판례 참조
4. 실무적 해결방안을 단계별로 제시하세요               #  실무 가이드
5. 사례에 없는 내용은 "제시된 사례집에서는 확인할 수 없습니다"라고 명시하세요  #  한계 인정

전문 법률 조언:"""

prompt = PromptTemplate(
    template=prompt_template,
    input_variables=["question"]
)

qa_chain = RetrievalQA.from_chain_type(
    llm=llm,                        #  위에서 설정한 LLM
    chain_type="stuff",             #  문서들을 하나로 합쳐서 처리
    retriever=retriever,            #  위에서 설정한 검색기
    chain_type_kwargs={"prompt": prompt},  #  법률 자문 프롬프트
    return_source_documents=True    #  참조 문서도 함께 반환
)

test_questions = [
    "온라인 게임에서 시스템 오류로 아이템이 사라졌는데, 게임회사가 복구를 거부하고 있습니다. 어떻게 해결할 수 있나요?",
    "인터넷 강의를 중도 해지하려고 하는데 과도한 위약금을 요구받고 있습니다. 정당한가요?",
    "무료체험 후 자동으로 유료전환되어 요금이 청구되었습니다. 환불 가능한가요?",
    "미성년자가 부모 동의 없이 게임 아이템을 구매했습니다. 환불받을 수 있는 방법이 있나요?",
    "온라인 교육 서비스가 광고와 다르게 제공되어 계약을 해지하고 싶습니다. 가능한가요?"
]

def classify_dispute_type(query):
    game_keywords = ["게임", "아이템", "계정", "캐릭터", "레벨", "길드", "온라인게임"]
    elearning_keywords = ["강의", "온라인교육", "이러닝", "수강", "환불", "화상교육"]
    web_keywords = ["웹사이트", "무료체험", "자동결제", "구독", "사이트"]
    
    query_lower = query.lower()
    
    if any(keyword in query_lower for keyword in game_keywords):
        return "게임"
    elif any(keyword in query_lower for keyword in elearning_keywords):
        return "이러닝"
    elif any(keyword in query_lower for keyword in web_keywords):
        return "웹콘텐츠"
    else:
        return "기타"


for i, question in enumerate(test_questions, 1):
    print(f"\n【테스트 {i}/5】")
    print(f" 질문: {question}")
    print(" 답변 생성 중...")
    
    # RAG 실행
    result = qa_chain.invoke({"query": question})
    qtype = classify_dispute_type(question)
    answer = result["result"]
    source_docs = result["source_documents"]
    
    print(f"\n 답변:")
    print("-" * 50)
    print(qtype)
    print(answer)
    
    # 참조 문서 정보
    print(f"\n 참조 문서:")
    for j, doc in enumerate(source_docs[:3], 1):
        page = doc.metadata.get('page', 'N/A')
        preview = doc.page_content[:80].replace('\n', ' ')
        print(f"   {j}. 페이지 {page}: {preview}...")
    
    print("\n" + "-" * 40)
# Out:
#  FAISS 벡터스토어 생성 완료 (104개 벡터)
#
# 【테스트 1/5】
#  질문: 온라인 게임에서 시스템 오류로 아이템이 사라졌는데, 게임회사가 복구를 거부하고 있습니다. 어떻게 해결할 수 있나요?
#  답변 생성 중...
#
#  답변:
# --------------------------------------------------
# 게임
# 온라인 게임에서 시스템 오류로 인해 아이템이 사라진 경우, 게임회사가 복구를 거부하는 상황에 대한 법률 조언을 다음과 같이 드립니다.
#
# 1. **사례 기반 답변**:
#    - 제시된 사례 1-가-1(2006)에서는 시스템 오류로 인해 아이템이 소멸된 경우, 계정 명의자가 아닌 신청인의 복구 요청이 거부되었습니다. 이는 계정 명의자만이 복구 요청을 할 수 있다는 게임사의 약관에 근거한 결정입니다.
#    - 사례 1-가-1(2009)에서는 시스템 오류로 인한 게임머니 소실 주장이 있었으나, 시스템 오류가 발생하지 않았다는 게임사의 판단에 따라 복구가 거부되었습니다.
#
# 2. **법적 근거 제시**:
#    - 일반적으로 게임사의 약관은 계약의 일부분으로 간주되며, 약관에 명시된 내용에 따라 복구 여부가 결정됩니다. 따라서 약관의 내용을 확인하는 것이 중요합니다.
#    - 민법 제250조와 제251조는 도난 또는 유실물에 대한 반환 청구에 관한 규정을 두고 있으나, 이는 주로 물리적 재화에 대한 규정입니다. 디지털 아이템의 경우, 게임사의 약관과 정책이 우선 적용될 수 있습니다.
#
# 3. **판례 참조**:
#    - 사례 1-가-1(2008)에서는 보안 서비스 미작동으로 인한 아이템 도난이 인정되어 복구가 이루어졌습니다. 이는 게임사의 서비스 미작동이 확인된 경우에 해당합니다.
#
# 4. **실무 가이드**:
#    - **약관 확인**: 게임사의 약관을 확인하여 시스템 오류로 인한 아이템 소실에 대한 복구 정책을 이해합니다.
#    - **증거 수집**: 시스템 오류가 발생한 시점의 스크린샷, 로그 파일 등 가능한 모든 증거를 수집합니다.
#    - **공식적인 요청**: 게임사에 공식적으로 복구 요청을 하고, 요청 내용과 증거를 명확히 전달합니다.
#    - **소비자 보호 기관 상담**: 한국소비자원 등 관련 기관에 상담을 요청하여 추가적인 법적 조언을 받습니다.
#    - **법적 대응 고려**: 게임사가 부당하게 복구를 거부한다고 판단될 경우, 법적 대응을 고려할 수 있습니다.
#
# 5. **한계 인정**:
#    - 제시된 사례집에서는 시스템 오류로 인한 아이템 소실에 대한 복구가 이루어진 사례는 확인할 수 없습니다. 각 사례는 특정 상황에 따라 다르게 처리되었으므로, 구체적인 상황에 따라 결과가 달라질 수 있습니다.
#
# 이와 같은 단계별 접근을 통해 문제를 해결할 수 있기를 바랍니다. 추가적인 법적 조언이 필요하다면 전문 변호사와 상담하시기를 권장합니다.
#
#  참조 문서:
#    1. 페이지 8: 1. 게임 3 게임1 ■ 1-가-1) 한국소비자원 조정전 상담사례2006_시스템 오류로 소멸된 아이템 복구 요구【사건개요】신청인은 피신청인이 제...
#    2. 페이지 28: 1. 게임 23 ■ 1-가-1) 한국소비자원 조정전 상담사례2009_시스템 오류로 인한 손실 아이템 복구 요구【사건개요】신청인은 2009. 9....
#    3. 페이지 30: 1. 게임 25 ■ 1-가-1) 한국소비자원 조정전 상담사례2009_해킹으로 손실된 아이템 복구 요청【사건개요】피청구인이 제공하는 게임서비스 가...
#
# ----------------------------------------
#
# 【테스트 2/5】
#  질문: 인터넷 강의를 중도 해지하려고 하는데 과도한 위약금을 요구받고 있습니다. 정당한가요?
#  답변 생성 중...
#
#  답변:
# --------------------------------------------------
# 이러닝
# 인터넷 강의를 중도 해지하려고 하는데 과도한 위약금을 요구받고 있는 상황에 대한 법률 조언을 드리겠습니다.
#
# 1. **사례 기반 답변:**
#    제시된 사례들에서 공통적으로 다루어진 문제는 중도 해지 시 위약금의 과도성입니다. 예를 들어, 2007년 한국소비자원 조정결정례에서는 계약 해지 시 위약금이 과도하게 책정된 경우가 있었습니다. 이 경우, 소비자분쟁해결기준에 따라 해지일까지의 이용일수에 해당하는 금액과 총 이용금액의 10%를 공제 후 환급하도록 규정되어 있습니다.
#
# 2. **법적 근거 제시:**
#    - **방문판매 등에 관한 법률 제29조**: 계약의 해지에 관한 규정.
#    - **소비자분쟁해결기준(공정위고시, 인터넷콘텐츠업)**: 해지일까지의 이용일수에 해당하는 금액과 총 이용금액의 10% 공제 후 환급.
#    - **디지털콘텐츠 이용표준약관 제26조**: 이용자의 청약철회와 계약 해제ㆍ해지에 관한 규정.
#
# 3. **판례 참조:**
#    - 2010년 사례에서는 피신청인이 신청인에게 이용요금에서 이용일수와 위약금을 공제한 금액을 환급하도록 결정되었습니다. 이는 소비자분쟁해결기준에 따라 처리된 것입니다.
#
# 4. **실무 가이드:**
#    - **계약서 검토**: 계약서에 명시된 해지 및 환불 조건을 확인하십시오.
#    - **공식적인 해지 요청**: 계약 해지 의사를 서면으로 명확히 전달하십시오.
#    - **소비자분쟁해결기준 적용 요청**: 위약금이 과도하다고 판단될 경우, 소비자분쟁해결기준에 따른 환급을 요청하십시오.
#    - **조정 신청**: 문제가 해결되지 않을 경우, 한국소비자원이나 전자거래분쟁조정위원회에 조정을 신청할 수 있습니다.
#
# 5. **한계 인정:**
#    제시된 사례집에서는 특정한 계약 조건이나 개별적인 상황에 대한 세부적인 정보는 확인할 수 없습니다. 따라서, 구체적인 법률 자문이 필요할 경우, 변호사와 상담하시기를 권장합니다.
#
# 이러한 조언이 귀하의 상황 해결에 도움이 되기를 바랍니다. 추가적인 질문이 있으면 언제든지 문의하십시오.
#
#  참조 문서:
#    1. 페이지 3: . 이러닝···········································································...
#    2. 페이지 62: 2. 이러닝 57 ■ 2-가 한국소비자원 조정결정례2007_인터넷교육서비스 중도해지 요구【사건개요】청구인은 2006. 2. 8. 피청구인이 운영...
#    3. 페이지 75: 콘텐츠분쟁조정 법리 연구 2부 - 타 분쟁조정사례 조사 - 70 하기 위하여 제정된 소비자분쟁해결기준은 인터넷컨텐츠업의 경우 해지일까지의 이용일...
#
# ----------------------------------------
#
# 【테스트 3/5】
#  질문: 무료체험 후 자동으로 유료전환되어 요금이 청구되었습니다. 환불 가능한가요?
#  답변 생성 중...
#
#  답변:
# --------------------------------------------------
# 이러닝
# 무료체험 후 자동으로 유료 전환되어 요금이 청구된 경우, 환불 가능 여부에 대한 법률 조언은 다음과 같습니다:
#
# 1. **사례 기반 답변**:
#    제시된 사례들에서는 무료 체험 후 자동 유료 전환에 대한 분쟁이 발생한 경우, 소비자가 중요한 계약 내용을 충분히 인지하지 못한 상태에서 유료 전환이 이루어졌다면, 이는 계약 체결 시 중요 내용의 명시 및 고지 의무를 위반한 것으로 판단될 수 있습니다.
#
# 2. **법적 근거 제시**:
#    - 「약관의 규제에 관한 법률」 제3조는 약관의 작성 및 설명 의무를 규정하고 있으며, 소비자가 계약의 중요한 내용을 충분히 이해할 수 있도록 명확하게 고지해야 한다고 명시하고 있습니다.
#    - 「소비자기본법」에 따른 소비자분쟁해결기준은 소비자에게 불리한 계약 조항을 제한하고 있습니다.
#
# 3. **판례 참조**:
#    - 사례 3-가에서는 피신청인이 계약 해지에 대한 내용을 충분히 고지하지 않았고, 소비자가 이를 쉽게 인지할 수 없었다는 점에서 환불 요구가 인정되었습니다.
#    - 사례 3-나에서도 유사하게, 소비자가 충분히 인지하기 어려운 방식으로 유료 전환이 이루어진 경우, 이는 소비자 보호 관련 법규를 위반한 것으로 판단되어 시정 대상이 되었습니다.
#
# 4. **실무 가이드**:
#    - **첫째**, 해당 서비스 제공자에게 계약 체결 시 중요한 내용이 충분히 고지되지 않았음을 서면으로 통지하고, 환불을 요청하십시오.
#    - **둘째**, 서비스 제공자가 환불을 거부할 경우, 한국소비자원이나 전자거래분쟁조정위원회에 분쟁 조정을 신청할 수 있습니다.
#    - **셋째**, 분쟁 조정 결과에 따라 환불이 이루어지지 않을 경우, 법적 절차를 통해 해결을 모색할 수 있습니다.
#
# 5. **한계 인정**:
#    제시된 사례집에서는 특정 서비스나 계약 조건에 대한 세부적인 내용은 확인할 수 없습니다. 각 사례의 구체적인 상황에 따라 결과가 달라질 수 있으므로, 개별적인 법률 상담을 통해 추가적인 조언을 받는 것이 좋습니다.
#
# 이러한 조언을 바탕으로, 귀하의 상황에 맞는 적절한 조치를 취하시기 바랍니다.
#
#  참조 문서:
#    1. 페이지 100: 3. 기타(웹) 95 ■ 3-가 한국소비자원 조정결정례2010_무료 이벤트 후 자동 소액 결제 요금 환급요구【사건개요】신청인은 2008. 12....
#    2. 페이지 69: 콘텐츠분쟁조정 법리 연구 2부 - 타 분쟁조정사례 조사 - 64 사용하여 반환받을 수 있는 서비스가 아니므로 미 이용기간에 해당하는 대금을 환급...
#    3. 페이지 103: 콘텐츠분쟁조정 법리 연구 2부 - 타 분쟁조정사례 조사 - 98 뿐만 아니라 이용자가 가입 후 해지를 원할 때 일정기간 해지를 못하게 한다거나 ...
#
# ----------------------------------------
#
# 【테스트 4/5】
#  질문: 미성년자가 부모 동의 없이 게임 아이템을 구매했습니다. 환불받을 수 있는 방법이 있나요?
#  답변 생성 중...
#
#  답변:
# --------------------------------------------------
# 게임
# 미성년자가 부모의 동의 없이 게임 아이템을 구매한 경우, 환불을 받을 수 있는 가능성은 여러 요인에 따라 달라질 수 있습니다. 아래에 제시된 사례와 관련 법령을 바탕으로 환불 가능성을 검토하고 실무적 해결 방안을 제시하겠습니다.
#
# 1. **사례 기반 답변**:
#    - 제시된 사례들에서 미성년자가 부모의 동의 없이 타인의 명의를 도용하거나 사술을 사용하여 결제를 진행한 경우, 법정대리인의 동의 없는 미성년자의 법률 행위는 원칙적으로 취소할 수 있습니다. 그러나 미성년자가 사술을 사용하여 자신이 능력자임을 표시한 경우에는 취소가 어려울 수 있습니다.
#
# 2. **법적 근거 제시**:
#    - **민법 제5조**: 미성년자의 능력 제한
#    - **민법 제17조**: 무능력자의 사술
#    - **민법 제741조**: 부당이득의 내용
#    - **민법 제753조 및 제755조**: 미성년자의 책임능력 및 책임무능력자의 감독자의 책임
#    - **대법원 판례(1971. 12. 14. 선고 71다2045 판결)**: 사술의 정의와 적용
#
# 3. **판례 참조**:
#    - 사례에서는 미성년자가 부모의 신용카드를 사용하여 결제를 진행한 경우, 사술을 사용한 것으로 판단되어 취소권을 행사할 수 없다는 결론이 내려졌습니다. 그러나 미성년자가 구입한 게임머니를 반환할 경우 환불이 가능하다는 점도 언급되었습니다.
#
# 4. **실무 가이드**:
#    - **1단계**: 구매 내역 및 결제 수단 확인
#      - 미성년자가 사용한 결제 수단과 구매 내역을 확인하여 부모의 동의 여부를 검토합니다.
#    - **2단계**: 게임사와의 협상
#      - 게임사에 연락하여 상황을 설명하고, 미성년자의 구매 행위가 법정대리인의 동의 없이 이루어졌음을 알립니다.
#    - **3단계**: 환불 요청
#      - 미성년자가 구매한 아이템이나 게임머니를 반환할 의사가 있음을 밝히고, 환불을 요청합니다.
#    - **4단계**: 법적 조치 검토
#      - 게임사가 환불을 거부할 경우, 법적 조치를 검토할 수 있습니다. 이때, 법률 전문가의 조언을 받는 것이 좋습니다.
#
# 5. **한계 인정**:
#    - 제시된 사례집에서는 특정한 상황에 대한 모든 가능성을 다루지 않았으므로, 각 사례의 구체적인 사실관계에 따라 결과가 달라질 수 있습니다. 추가적인 법적 조언이 필요할 수 있습니다.
#
# 위의 가이드라인을 참고하여 환불 절차를 진행하시기 바랍니다. 추가적인 법적 조언이 필요하다면, 전문 변호사와 상담하시기를 권장합니다.
#
#  참조 문서:
#    1. 페이지 50: 1. 게임 45 ■ 1-나 전자거래분쟁조정위원회 조정결정례2008_부당결제대금 반환 청구【사건개요】신청인의 자녀는 2004. 4. 22. 피신청...
#    2. 페이지 53: 콘텐츠분쟁조정 법리 연구 2부 - 타 분쟁조정사례 조사 - 48  - 피신청인  ㆍ 피신청인은 구매당시 구매자에게 전화를 하였을 당시 전화를 받...
#    3. 페이지 52: 1. 게임 47 신청인의 미성년 아들이 신청인의 이름을 도용하여 피신청인사 사이트에 회원 가입 후 2008. 9. 23.부터 같은 해 9. 25...
#
# ----------------------------------------
#
# 【테스트 5/5】
#  질문: 온라인 교육 서비스가 광고와 다르게 제공되어 계약을 해지하고 싶습니다. 가능한가요?
#  답변 생성 중...
#
#  답변:
# --------------------------------------------------
# 기타
# 온라인 교육 서비스가 광고와 다르게 제공되어 계약을 해지하고 싶다는 문의에 대해 다음과 같이 답변 드리겠습니다.
#
# 1. **사례 기반 답변**:
#    - 제시된 사례들에서는 온라인 교육 서비스의 계약 해지 및 환불에 대한 다양한 분쟁이 다루어졌습니다. 특히, 신청인이 개인 사정이나 서비스 불만족으로 인해 계약 해지를 요청한 경우가 많았습니다.
#
# 2. **법적 근거 제시**:
#    - 관련 법령으로는 「방문판매 등에 관한 법률」 제29조(계약의 해지)와 제30조(계약의 해지 또는 해제의 효과와 위약금 등)가 있습니다. 이 법령에 따르면, 소비자는 계약을 해지할 수 있으며, 해지로 인해 발생하는 손실을 현저하게 초과하는 위약금을 청구할 수 없습니다.
#    - 또한, 「소비자기본법」에 따른 소비자분쟁해결기준(공정위고시, 인터넷콘텐츠업)도 참고할 수 있습니다.
#
# 3. **판례 참조**:
#    - 사례 69에서는 신청인이 계약 해지 의사를 표시하고 환급을 요구하였으나, 피신청인이 투입된 비용을 이유로 환급을 제한하려 했습니다. 그러나 법령에 따라 계약 해지가 적법하게 이루어졌고, 과도한 위약금 청구는 받아들여지지 않았습니다.
#    - 사례 57에서는 피청구인이 과도한 위약금을 공제하려 했으나, 소비자보호법 시행령에 따라 계약서에 기재된 금액을 기준으로 환급해야 한다고 판단되었습니다.
#
# 4. **실무 가이드**:
#    - **첫째**, 계약서 및 약관을 검토하여 환불 및 계약 해지 조건을 확인하세요.
#    - **둘째**, 계약 해지 의사를 명확히 표시하고, 관련 증빙 자료(예: 광고와 실제 서비스의 차이점)를 준비하세요.
#    - **셋째**, 피신청인과의 협의를 통해 환불 조건을 조정할 수 있는지 확인하세요. 만약 협의가 어려울 경우, 전자거래분쟁조정위원회나 한국소비자원에 중재를 요청할 수 있습니다.
#    - **넷째**, 법적 절차를 고려할 경우, 관련 법령과 판례를 근거로 하여 법률 전문가의 자문을 받는 것이 좋습니다.
#
# 5. **한계 인정**:
#    - 제시된 사례집에서는 광고와 실제 서비스의 차이로 인한 계약 해지에 대한 구체적인 사례는 확인할 수 없습니다. 따라서, 구체적인 상황에 따라 추가적인 법률 자문이 필요할 수 있습니다.
#
# 이와 같은 절차를 통해 문제를 해결하시기를 권장드립니다. 추가적인 법률 자문이 필요하시면 전문가와 상담하시기 바랍니다.
#
#  참조 문서:
#    1. 페이지 94: 2. 이러닝 89 상기 내용을 살펴보면, 신청인은 청약철회 기간을 지났으므로 위 계약의 청약을 철회할 수는 없는 것으로 보인다. 피신청인은 위 ...
#    2. 페이지 93: 콘텐츠분쟁조정 법리 연구 2부 - 타 분쟁조정사례 조사 - 88 ■ 2-다 전자거래분쟁조정위원회 조정결정례2008_온라인 동영상 강의 계약 해지...
#    3. 페이지 62: 2. 이러닝 57 ■ 2-가 한국소비자원 조정결정례2007_인터넷교육서비스 중도해지 요구【사건개요】청구인은 2006. 2. 8. 피청구인이 운영...
#
# ----------------------------------------
